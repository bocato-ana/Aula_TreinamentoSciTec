# %% [markdown]
# 🚀 Python: Do Zero ao Intermediário na Scitec
# Instrutora: Ana (Gerente de Dados)
#
# Objetivo: Consolidar as bases para dominarmos o Streamlit no futuro!
#
# 1. 🏗️ A importância da Sintaxe: A Ordem Importa!
# Antes de começarmos, precisamos entender que o computador é "teimoso". Ele só entende se falarmos na ordem exata que ele espera.
#
# Regra de Ouro: A ordem dos fatores ALTERA o produto na programação.
#
# ✅ print(f"Olá") -> Funciona! Você chamou a função e passou o texto.
#
# ❌ (f"Olá")print -> Erro de Sintaxe! O Python tenta ler o texto primeiro e não sabe o que fazer com o "print" depois.

# %%
print('Olá Mundo')
# Out:
# Olá Mundo

# %% [markdown]
# Durante a programação é normal fazer "Comentários", eles ajudam outros programadores a entender o que o código faz

# %%
#Deseja boas vindas para os novos programadores de python
nome = str(input('Qual seu nome? '))
print(f'Olá {nome}')
# Out:
# Olá ana

# %% [markdown]
# *DEFININDO VARIÁVEIS*
#
# 🚫 O que NÃO pode fazer (Regras de Ouro)
# ❌ Começar com números: 1variavel está errado. O correto é variavel1.
#
# ❌ Usar espaços: nome do aluno não funciona. Use nome_do_aluno.
#
# ❌ Usar caracteres especiais: Nada de !, @, #, $, % ou acentos como ç, á.
#
# ❌ Usar palavras reservadas: Não dê nomes como print, if, for ou while para suas variáveis.

# %%
Nome_aluno = 'Gustavo' 
nome_aluno = 'Gustavo'

1nota = 10
nota_1 = 10

# %% [markdown]
# Constantes em Python são diferentes de constantes em outras linguas, não existe uma forma de 'forçar a existencia' de uma constate, é pura convenção

# %%
#CONSTANTE
PI = 3.14

#VARIÁVEL
pi = 3.14

# %% [markdown]
# 2. 📝 Saída de Dados e f-Strings (O Jeito Moderno)
# Na Scitec, vamos lidar com muitos dados. O print() com f"" (f-string) permite injetar variáveis dentro de textos de forma limpa.
#
# O f antes das aspas avisa ao Python: "Ei, fique atento às chaves {}!"

# %%
nome_projeto = "Dashboard de Vendas"
versao = 1.12

# Usando f-strings com emojis para relatórios visuais
print(f"🚀 Iniciando projeto: {nome_projeto}")
print(f"📌 Versão atual: {versao:.1f}") # o :.1f força uma casa decimal
# Out:
# 🚀 Iniciando projeto: Dashboard de Vendas
# 📌 Versão atual: 1.12

# %% [markdown]
# 🏷️ 5. Type Hinting:
# No Python básico, as variáveis são "livres" (tipagem dinâmica). Você pode criar uma variável com um número e depois mudar para um texto. Isso é perigoso em grandes projetos!
#
# O Type Hinting (Dica de Tipo) serve para documentar o seu código enquanto você escreve. Ele diz para outros desenvolvedores (e para o VS Code/Jupyter) o que aquela função espera receber.

# %%
nome = 'Ana'
idade = 55

print(f'Meu nome é {nome} e tenho {idade} anos')
# Out:
# Meu nome é Ana e tenho 55 anos

# %%
nome = input('Qual seu nome? ')
idade = input('Quantos anos você tem? ')

print(f'Meu nome é {nome} e tenho {idade} anos')
# Out:
# Meu nome é 678 e tenho 65 anos

# %%
nome: str = 'Bob'
idade : int = 20

nascimento = int(input('Quando você nasceu? '))
#força o usuário a digitar certo, facilita em grandes projetos
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 4
#       1 nome: str = 'Bob'
#       2 idade : int = 20
# ----> 4 nascimento = int(input('Quando você nasceu? '))
#       5 #força o usuário a digitar certo, facilita em grandes projetos
#
# ValueError: invalid literal for int() with base 10: 'ana'
